# %% [markdown]
# # **Source-Photometry Lephare Identification Tool (SPLIT) for star-galaxy separation**

# %% [markdown]
# Just the statistical functions to plot charateristic of classifiers

# %%
source_mask = photoz_cat["ZSPEC"]>0
df_plot = photoz_cat[photoz_cat["ERR_MAG_OBS0"]<0.1].dropna()

plt.figure()
plt.hist2d(df_plot["ERR_MAG_OBS1"], df_plot["P_STAR"], bins=(np.arange(0,2.005,0.05),np.arange(0,1.001,0.05)), cmap='gist_stern')
plt.colorbar(label="counts")
plt.show()

plt.figure()
plt.hist(df_plot["P_STAR"], bins=np.arange(0,1.01,0.01))
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, thresholds = roc_curve(
    df_plot["IS_STAR"],
    df_plot["P_STAR"],
    pos_label=1
)
pstar_threshold
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(5,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.plot([0,1], [0,1], "k--", alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

y_true = df_plot["IS_STAR"].values
y_score = df_plot["P_STAR"].values

precision, recall, thresholds = precision_recall_curve(
    y_true,
    y_score
)

plt.figure(figsize=(5,5))
plt.plot(recall, precision)
plt.plot([1,0], [0,1], "k--", alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np

target_precision = 0.6

valid = precision[:-1] >= target_precision
import numpy as np

target_purity = 0.6
valid = precision[:-1] >= target_purity

if not np.any(valid):
    print("No threshold reaches 95% purity")
else:
    idx = np.where(valid)[0]
idx

if not np.any(valid):
    raise RuntimeError("No threshold reaches 95% precision")

# among valid thresholds, choose the one with MAX recall
best_idx = np.argmax(recall[:-1][valid])
threshold_idx = np.where(valid)[0][best_idx]
threshold_idx
pstar_threshold = thresholds[threshold_idx]
pstar_threshold
