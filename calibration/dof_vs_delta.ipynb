# %% [markdown]
# # Variation of $k$ as a function of $\Delta${$T_{eff},\log(g), Fe/H$}

# %% [markdown]
# The values presented here have been derived from other notebooks in the file

# %%
from imports import *

# %% [markdown]
# ## $k$ VS $\Delta T_{eff}$

# %% [markdown]
# mock stars: {$T_{eff} = \left\{3800, 7200\right\}$, $\log(g) = 4.5$, $Fe/H = 0.0$}

# %%
d_Teff = [1600,800,400,200,100,50,25,10,5]
kTeff_Teff3800 = [4.97, 4.99, 4.95, 4.92, 4.80, 4.66, 4.51, 4.35, 4.23]
mTeff_Teff3800 = np.array([2.71, 2.41, 2.44, 2.42, 2.44, 2.11, 2.13, 2.11, 2.11])

kTeff_Teff7200 = [5, 5, 4.84, 4.67, 4.47, 4.34, 4.15, 4.06, 4.04]
mTeff_Teff7200 = np.array([3, 2.7, 2.44, 2.43, 2.12, 2.12, 1.82, 1.82, 1.82])



plt.figure()
plt.plot(d_Teff, kTeff_Teff3800, c='k', linestyle='-', label="k; Teff = 3800")
plt.plot(d_Teff, mTeff_Teff3800+2, c='k', linestyle='--', label="m; Teff = 3800")

square = lambda x : x / (x+100)
plt.plot(d_Teff, square(np.array(d_Teff))+4, c='b', linestyle='-', label="test")


plt.semilogx(d_Teff, kTeff_Teff7200, c='r', marker='o', linestyle='-', label="k; Teff = 7200")
plt.semilogx(d_Teff, mTeff_Teff7200+2, c='r', marker='o',linestyle='--', label="m; Teff = 7200")

plt.ylim(3.5, 5.2)
plt.xlabel(f"$\Delta Teff$")
plt.ylabel(f"$k$")
plt.legend()
plt.show()
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_13904/4018194369.py:22: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel(f"$\Delta Teff$")

# %% [markdown]
# ## $k$ VS $\Delta \log(g)$

# %% [markdown]
# mock stars: {$T_{eff} = \left\{3800, 7200\right\}$, $\log(g) = 2.5$, $Fe/H = 0.0$}

# %%
d_logg = [0.5, 0.25, 0.1, 0.05, 0.01]
klogg_Teff3800 = [4.53, 4.33, 4.15, 4.05, 3.94]
mlogg_Teff3800 = np.array([2.03, 2.11, 1.81, 1.83, 1.81])

klogg_Teff7200 = [4.57, 4.42, 4.25, 4.16, 4.05]
mlogg_Teff7200 = np.array([2.42, 2.11, 2.11, 2.11, 1.82])


plt.figure()
plt.semilogx(d_logg, klogg_Teff3800, c='k', linestyle='-', label="k; eff = 3800")
# plt.semilogx(d_logg, mlogg_Teff3800+2, c='k', linestyle='--', label="m; Teff = 3800")

plt.semilogx(d_logg, klogg_Teff7200, c='r', marker='o', linestyle='-', label="k; Teff = 7200")
# plt.semilogx(d_logg, mlogg_Teff7200+2, c='r', marker='o',linestyle='--', label="m; Teff = 7200")

# square = lambda x : x / (x+0.5)
# plt.plot(d_logg, square(np.array(d_logg))+4, c='b', linestyle='-', label="test")

plt.xlabel(f"$\Delta \log(g)$")
plt.ylabel(f"$k$")
plt.ylim(3.5, 5.0)
plt.legend()
plt.show()
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\D'
# <>:19: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_13904/3557350067.py:19: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel(f"$\Delta \log(g)$")

# %% [markdown]
# ## $k$ VS $\Delta FeH$

# %%
d_feh = [0.5, 0.25, 0.1, 0.05, 0.01, 0.005]
kfeh_Teff3800 = [4.59, 4.41, 4.20, 4.07, 3.96, 3.96]
mfeh_Teff3800 = np.array([2.44, 2.11, 1.81, 1.81, 1.81, 1.81])

kfeh_Teff7200 = [4.52, 4.36, 4.22, 4.17, 4.15, 4.11]
mfeh_Teff7200 = np.array([2.43, 2.13, 1.81, 2.11, 1.81, 2.12])

plt.figure()
plt.semilogx(d_feh, kfeh_Teff3800, c='k', linestyle='-', label="k; Teff = 3800")
plt.semilogx(d_feh, mfeh_Teff3800+2, c='k', linestyle='--', label="m; Teff = 3800")

plt.semilogx(d_feh, kfeh_Teff7200, c='r', marker='o', linestyle='-', label="k; Teff = 7200")
plt.semilogx(d_feh, mfeh_Teff7200+2, c='r', marker='o',linestyle='--', label="m; Teff = 7200")

# square = lambda x : x / (x+0.25)
# plt.plot(d_feh, square(np.array(d_feh))+4, c='b', linestyle='-', label="test")

plt.ylim(3.5, 5.2)
plt.xlabel(f"$\Delta Fe/H$")
plt.ylabel(f"$k$")
plt.legend()
plt.show()
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\D'
# <>:19: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_13904/3166253361.py:19: SyntaxWarning: invalid escape sequence '\D'
#   plt.xlabel(f"$\Delta Fe/H$")
