# %% [markdown]
# # **SED CALIB**
#
# Tests on a sed library with two degrees of freedom: alpha (normalisation) and Teff.

# %% [markdown]
# ## **0. Initialisation**

# %% [markdown]
# ### 0.1 Packages

# %%
### Libs ###
from imports import *

#custom
from src.download_bt_spectra import download_bt_spectra
import src.data_manipulations as dm; reload(dm)
import src.plot_tools as pt; reload(pt)
import src.photometry_errors as pe; reload(pe)
from src.format_to_dat import format_to_lephareinput 

#lephare
import lephare as lp
config = lp.default_stargal_config.copy()

base_dir = os.path.abspath(os.path.join(os.getcwd()))
sys.path.append(base_dir)

# %matplotlib inline

# %% [markdown]
# ### 0.2 Important inputs

# %%
n_sources = 10000 # Number of sources per template to sample
max_row_lephare = 500000 # Number of rows to loop on with zphota
work_with_absmags = True # If true, mag_obs --> mag_obs - deltam
return_dm = True # return dm in mock table
if work_with_absmags == True: #must be true in this case
    return_dm = True


#physical quantities of seds to download.
#WARNING: The number of seds downloaded is equal to len(teff_values) x len(logg_values) x (metallicity_values), 
#so it could need a lot of space!
#physical quantities
teff_values = list(range(800, 12001, 100)) + list(range(13000, 20001, 1000)) + list(range(22000, 50001, 2000))
logg_values = 3.0
metallicity_values = 0.0

#if true, delete temporary files
clean_cache = True #lephare sedlib and maglib cache
clean_seds = False #local directory seds

# %% [markdown]
# ### 0.3 Download spectra
#
# Use ``download_bt_spectra.py``

# %%
#--- Downloading parameters--- 
#model
MODEL = "bt-nextgen-agss2009"
BASE_URL = f"https://svo2.cab.inta-csic.es/theory/newov2/ssap.php?model={MODEL}" #website to download from

#dl directory
sed_name = f"logg{logg_values}feh{metallicity_values}" #WARNING: name after fixed parameter
local_dir = f'data/tests/bt_spectra_{sed_name}'#directory to download in
OUTPUT_DIR = os.path.abspath(os.path.join(base_dir, "data/bt_spectra"))

#Control wavelength range and resolution
LMIN = 1145.0   # Å, set to None to keep full range
LMAX = 25005.0  # Å
DL   = 5.0      # Å, set to None to keep original sampling
wl_norm = 10000 # Å. Lot of space earned
make_sed_list = True # create sed list in the same folder
overwrite_seds = False # if true, overwrite identically named seds
list_name = f"bt_star_sed_{sed_name}"

#--- Download ---
download_bt_spectra(MODEL=MODEL, BASE_URL=BASE_URL, OUTPUT_DIR=OUTPUT_DIR,
    teff_values=teff_values, logg_values=logg_values, metallicity_values=metallicity_values,
    LMIN=LMIN, LMAX=LMAX, DL=DL, wl_norm=wl_norm,
    make_sed_list=make_sed_list, overwrite_seds=overwrite_seds, list_name=list_name,)
# Out:
# Downloading main VOTABLE...
# 13627 <TR> lines found in VOTABLE.
# 88 spectra found matching with the chosen grid.
# T_eff=2600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=2700, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=2800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=2900, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3100, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3300, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3500, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3700, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=3900, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4100, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4300, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4500, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4700, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=4900, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5100, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5300, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5500, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5700, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=5900, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6100, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6300, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6500, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6700, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=6900, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=7000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=7200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=7400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=7600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=7800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=8000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=8200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=8400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=8600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=8800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=9000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=9200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=9400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=9600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=9800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=10000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=10200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=10400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=10600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=10800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=11000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=11200, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=11400, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=11600, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=11800, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=12000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=13000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=14000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=15000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=16000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=17000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=18000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=19000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=20000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=22000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=24000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=26000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=28000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=30000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=32000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=34000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=36000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=38000, logg=3.0, Fe/H=0.0 already exists. Pass.
# T_eff=40000, logg=3.0, Fe/H=0.0 already exists. Pass.
# All available spectrum have been downloaded and formated.

# %% [markdown]
# ## **1. Run first LePHARE steps**

# %%
filt_fname = "lsst_griz"
sedlib_prefix = "BT_SEDs_"
maglib_prefix = "BT_LSST_griz_"

# %% [markdown]
# ### 1.0 Filter to lib (optional)

# %%
# If you want to add more or less filters

#--- With LSST filters ---
filter_path = f"{base_dir}/data/filt" 

filter_rep = lp.keyword("FILTER_REP", filter_path)
filter_list = lp.keyword("FILTER_LIST",
"BuzzardLSSTg.res,BuzzardLSSTr.res,\
     BuzzardLSSTi.res,BuzzardLSSTz.res")

filterLib = lp.Filter(config_keymap={"FILTER_REP":filter_rep,
                                   "FILTER_LIST":filter_list,
                                   "TRANS_TYPE":lp.keyword("TRANS_TYPE", "0"),
                                   "FILTER_CALIB":lp.keyword("FILTER_CALIB", "0"), #"0,0,0,0,0,0"
                                   "FILTER_FILE":lp.keyword("FILTER_FILE", filt_fname)})


filterLib.run()
# Out:
# # NAME                        IDENT      Lbda_mean Lbeff(Vega)       FWHM     AB-cor    TG-cor      VEGA M_sun(AB)   CALIB      Lb_eff    Fac_corr
# BuzzardLSSTg.res              1             0.4799      0.4700      0.1453   -0.0893   -0.2698  -20.6973    5.1149       0      0.4719      1.0000
# BuzzardLSSTr.res              2             0.6221      0.6133      0.1391    0.1458    0.2557  -21.5085    4.6531       0      0.6165      1.0000
# BuzzardLSSTi.res              3             0.7541      0.7475      0.1302    0.3662    0.5795  -22.1521    4.5371       0      0.7499      1.0000
# BuzzardLSSTz.res              4             0.8682      0.8659      0.1011    0.5171    0.7616  -22.6138    4.5165       0      0.8658      1.0000
# [<lephare._lephare.flt at 0x781762e781d0>,
#  <lephare._lephare.flt at 0x781762e7bf50>,
#  <lephare._lephare.flt at 0x781762e788f0>,
#  <lephare._lephare.flt at 0x781762eb8cb0>]

# %% [markdown]
# ### 1.1 Sed to Lib

# %%
#--- With BT ---
SED_list_path = f"{base_dir}/{local_dir}/{list_name}.list"
sedLib = lp.Sedtolib(config_keymap={
    "STAR_SED": lp.keyword("STAR_SED", SED_list_path),
    "STAR_FSCALE": lp.keyword("STAR_FSCALE", "3.432E-09"),
    "STAR_LIB": lp.keyword("STAR_LIB", f'{sedlib_prefix}{sed_name}')},)
    
sedLib.run(typ="S")
# Out:
# #######################################
# # It s translating SEDs to binary library #
# # with the following options :
# # Config file     :
# # Library type     : STAR
# # STAR_SED    :/home/hallouin/Documents/t_hall/lephare-u-Tototime-sedlib-calibration/calibration/data/tests/bt_spectra_logg3.0feh0.0/bt_star_sed_logg3.0feh0.0.list
# # STAR_LIB    :BT_SEDs_logg3.0feh0.0
# # STAR_LIB doc:/home/hallouin/.cache/lephare/work/lib_bin/BT_SEDs_logg3.0feh0.0.doc
# # STAR_FSCALE :0.0000
# #######################################
# Number of SED in the list 88

# %% [markdown]
# ### 1.2 MagGal

# %%
maglib = lp.MagGal(config_keymap=lp.all_types_to_keymap(config))

star_lib_in = f"{sedlib_prefix}{sed_name}"
star_lib_out = f"{maglib_prefix}{sed_name}"
maglib.run(typ="S",
    star_lib_in=star_lib_in,
    star_lib_out=star_lib_out,
    filter_file=filt_fname,
    magtype="AB",
    mod_extinc="0",
    extinc_law="calzetti.dat",
    em_dispersion="0",
    lib_ascii="YES",
    z_step="0.0,0,0")
# Out:
# #######################################
# # It s computing the SYNTHETIC MAGNITUDES #
# # For Gal/QSO libraries with these OPTIONS #
# # with the following options :
# # Config file     :
# # Filter file     : lsst_griz
# # Magnitude type     : AB
# # COSMOLOGY   :70.0000,0.3000,0.7000
# # STAR_LIB_IN    :/home/hallouin/.cache/lephare/work/lib_bin/BT_SEDs_logg3.0feh0.0(.doc & .bin)
# # STAR_LIB_OUT   :/home/hallouin/.cache/lephare/work/lib_mag/BT_LSST_griz_logg3.0feh0.0(.doc & .bin)
# # LIB_ASCII   YES
# # CREATION_DATE Thu Mar 26 17:20:50 2026
# #############################################

# %% [markdown]
# ## **2. Make mock catalog from mag lib**

# %% [markdown]
# ### 2.1 Load magbin into pandas and sed physical data

# %%
#--- copy-paste maglib from the lepahre cache folder ---
from pathlib import Path
import shutil
cache_dir = Path.home() / f".cache/lephare/work/lib_mag" 
paste_path = f"{base_dir}/{local_dir}/"
shutil.copy(f"{cache_dir}/{star_lib_out}.dat", paste_path)
# Out:
# '/home/hallouin/Documents/t_hall/lephare-u-Tototime-sedlib-calibration/calibration/data/tests/bt_spectra_logg3.0feh0.0/BT_LSST_griz_logg3.0feh0.0.dat'

# %%
#--- Convert to pandas ---
maglib = dm.maglib_to_pandas(f"{base_dir}/{local_dir}/{star_lib_out}.dat", filters=['g','r','i','z'])

# %%
#--- Generate sed grid with associated physical values from names ---
class SED_GRID:
    '''
    For a SED set dependent on physical parameters, construct a coherent grid.
    '''
    def __init__(self, list_path):
        """Load SED list."""
        sed_list = []
        with open(list_path, 'r') as file:
            for line in file:
                line = line.strip()
                if line.startswith('#') or not line:
                    continue
                filepath = line.split()[0]
                sp_type = filepath.split('/')[-1].replace('.sed', "")
                sed_list.append(sp_type)
        self.sed_list = sed_list
        self.sed_grid = None

    def build(self):
        """Build the sed grid [Id, Teff, logg, FeH] from filenames."""
        pattern = r"Teff([-\d\.]+)_logg([-\d\.]+)_FeH([-\d\.]+)"
        sed_grid = []
        for Id, s in enumerate(self.sed_list):
            match = re.search(pattern, s)
            if match:
                Teff, logg, FeH = match.groups()
                Teff, logg, FeH = float(Teff), float(logg), float(FeH)
                sed_grid.append([Id, Teff, logg, FeH])
        self.sed_grid = np.array(sed_grid)
        return self.sed_grid

sed_grid_path = f'{base_dir}/{local_dir}/{list_name}.list'
sed_grid_init = SED_GRID(sed_grid_path)
sed_grid = sed_grid_init.build()
sed_grid[:,0] = sed_grid[:,0] + 1
sed_grid = pd.DataFrame(sed_grid, columns=["model", "teff", "logg", "feh"])

# %%
#--- Merge in the one table from which we generate mock mags ---
maglib = dm.join_tables(maglib, (sed_grid, "model", "model"))
maglib[:3]
# Out:
#    model  N_filt  magnitude_g  magnitude_r  magnitude_i  magnitude_z     teff  \
# 0    1.0     4.0     -2.00368     -1.72450     -1.47536     -1.32808  10000.0
# 1    2.0     4.0     -2.02598     -1.73881     -1.48472     -1.33342  10200.0
# 2    3.0     4.0     -2.04584     -1.75176     -1.49345     -1.33827  10400.0
#
#    logg  feh
# 0   3.0  0.0
# 1   3.0  0.0
# 2   3.0  0.0

# %% [markdown]
# ### 2.2 Generate sources

# %%
#--- Class to sample sources and apply errors ---
class MockPhotometry:        
    @staticmethod
    def generate_sources_from_magabs(mags, ref_index, mag_min, mag_max, N, method="uniform", return_dm=False):
        """
        Generates N sources from a SED in magnitudes, with the reference band
        uniformly distributed between mag_min and mag_max. The other bands are
        shifted to preserve colors.
        """
        mags = np.array(mags)
        Nband = len(mags)
        if method == 'uniform':
            ref_mags = np.random.uniform(low=mag_min, high=mag_max, size=N)
            delta_M = ref_mags - mags[ref_index]
            sources = mags[None, :] + delta_M[:, None]
        else:
            raise NotImplementedError(f"Method '{method}' not implemented yet")
        if return_dm == True:
            return sources, delta_M[:, None]
        else:
            return sources

    @staticmethod
    def generate_sources_from_table(table, mag_cols, ref_index, mag_min, mag_max, N_per_star, 
                                    method="uniform", return_full_table=False, return_dm=False):
        """
        Generates mock sources for each source from a Pandas table.
        """
        mock_list = []

        for _, row in table.iterrows():
            mags = row[mag_cols].values
            mock_mags = MockPhotometry.generate_sources_from_magabs(mags, ref_index, mag_min, mag_max, N_per_star, method, return_dm)

            if return_dm == True:
                sources = mock_mags[0]
                sources_dm = mock_mags[1]
                df_sources = pd.DataFrame(np.concat((sources,sources_dm), axis=1), columns=np.concat((mag_cols,["mag_dm"])))
            else:
                sources = mock_mags
                df_sources = pd.DataFrame(sources, columns=mag_cols)

            if return_full_table:
                # dupliquer les autres colonnes
                other_cols = row.drop(labels=mag_cols)
                df_other = pd.DataFrame([other_cols.values]*N_per_star, columns=other_cols.index)

                df_sources = pd.concat([df_other.reset_index(drop=True),
                                        df_sources.reset_index(drop=True)],
                                        axis=1)

            mock_list.append(df_sources)

        df_mock = pd.concat(mock_list, ignore_index=True)

        return df_mock
    
    @staticmethod
    def generate_errors(table, mag_columns, models=None, model_names=None, suffix="_err_sim", error_cut=None, error_factor=1,
                random_state=None, format="MMEE", add_errors=True, keep_true_mags=True, default_error_value=None):
        """ 
        Generate photometric errors using PhotometricErrorModel and optionally
        add Gaussian noise to magnitudes.
        """

        if default_error_value is not None:
            table_with_errs = table.copy()
            for col in mag_columns:
                table_with_errs[col + suffix] = np.full(len(table_with_errs), default_error_value)
                
            if add_errors:
                #sample noisy cols
                rng = np.random.default_rng(random_state)
                mags = table_with_errs[mag_columns].to_numpy(dtype=float)
                err_cols = [c + suffix for c in mag_columns]
                sigmas = table_with_errs[err_cols].to_numpy(dtype=float)
                noise = rng.normal(loc=0.0, scale=sigmas)
                mags_obs = mags + noise
                #add to table
                table_with_errs[mag_columns] = mags_obs
                table_with_errs[err_cols] = sigmas

            if keep_true_mags:
                true_cols = [c + "_true" for c in mag_columns]
                table_with_errs[true_cols] = mags

            return table_with_errs

        # Generate errors
        table_with_errs = pe.PhotometricErrorModel().sample_errors_on_catalog(
            table, mag_columns=mag_columns, models=models, model_names=model_names, format=format)

        if not add_errors:
            return table_with_errs

        rng = np.random.default_rng(random_state)
        mags = table_with_errs[mag_columns].to_numpy(dtype=float)
        err_cols = [c + suffix for c in mag_columns]
        sigmas = table_with_errs[err_cols].to_numpy(dtype=float)*error_factor

        # Gaussian noise
        # convert to flux before adding gaussian noise
        fluxes = 10**(-0.4*mags)
        f_err = np.log(10)/2.5*fluxes*sigmas
        noise = rng.normal(loc=0.0, scale=f_err)
        f_obs = fluxes + noise
        mags_obs = -2.5*np.log10(f_obs)


        if error_cut is not None:
            mask_low_snr = error_cut < sigmas
            mags_obs[mask_low_snr] = np.nan
            sigmas[mask_low_snr] = np.nan

        if keep_true_mags:
            true_cols = [c + "_true" for c in mag_columns]
            table_with_errs[true_cols] = mags

        table_with_errs[mag_columns] = mags_obs
        table_with_errs[err_cols] = sigmas

        return table_with_errs

# %%
#--- Sampling sources from only one source of the list ---
maglib_reduced = maglib.iloc[[23]]
maglib_reduced
# Out:
#     model  N_filt  magnitude_g  magnitude_r  magnitude_i  magnitude_z    teff  \
# 23   24.0     4.0      3.81947      2.56048     0.507095    -0.555312  2700.0
#
#     logg  feh
# 23   3.0  0.0

# %%
mock_mags = MockPhotometry.generate_sources_from_table(table=maglib_reduced, #panda table
    mag_cols=['magnitude_g','magnitude_r','magnitude_i','magnitude_z'], #mag cols
    ref_index=0, #mag col ref
    mag_min=20, #minimum mag col ref
    mag_max=26, #maximum mag col ref
    N_per_star=n_sources, #n source per row
    method='uniform', #sampling method
    return_full_table=True,
    return_dm=return_dm)

# %%
pt.plot_histograms(mock_mags, ["magnitude_r", "magnitude_i"], alpha=0.6, edgecolor="k")

# %% [markdown]
# ### 2.3 Generate errors and observed mags

# %% [markdown]
# Here we generate errors from a gamma error model function of magnitude, made from DP1 error distribution.
#
# Note: the model is quite limited in high/low luminosity due ot lack of sources in the original file.

# %%
dp1_ECDFS = pd.read_csv(f"{base_dir}/data/catalogs/DP1_ECDFS_photometry.csv")
dp1_ECDFS = dp1_ECDFS[(dp1_ECDFS["u_cModelMag"]<26.5) & (dp1_ECDFS["g_cModelMag"]<26.5) & (dp1_ECDFS["r_cModelMag"]<26.5) 
                        & (dp1_ECDFS["i_cModelMag"]<26.5) & (dp1_ECDFS["z_cModelMag"]<26.5) & (dp1_ECDFS["y_cModelMag"]<26.5)]

# %% [markdown]
# Make error model

# %%
pem_dp1_ECDFS = pe.PhotometricErrorModel()

dp1_ECDFS_models = pem_dp1_ECDFS.model_collection(
    x_lists=dp1_ECDFS[["u_cModelMag","g_cModelMag","r_cModelMag","i_cModelMag","z_cModelMag","y_cModelMag"]], #mag list or panda.series
    sigma_lists=dp1_ECDFS[["u_cModelMagErr","g_cModelMagErr","r_cModelMagErr","i_cModelMagErr","z_cModelMagErr","y_cModelMagErr"]], #mag err list or panda.series
    model_names=["u", "g", "r", "i", "z", "y"], #model name list
    sharpness_factor=1.05, #lower queue length of the gamma distribution
    delta_mag=0.005, #bin length in magnitude
    min_per_bin=None, #minimum per bin in mag, to avoid poorly populated bins
    )

# %% [markdown]
# Apply

# %%
#--- Generate errors ---
mock_cat = MockPhotometry.generate_errors(mock_mags, 
    mag_columns = ['magnitude_g','magnitude_r','magnitude_i','magnitude_z'],
    models = dp1_ECDFS_models, #model dict
    model_names = ["g", "r", "i", "z"], #model name to use for each column
    format="MEME", #output column order
    error_cut=5,
    default_error_value=None, #if you want same error for each source
    add_errors=True, #sample observed mags
    error_factor=200
    )


#--- Optional: Revert to absolute magnitudes ---
if work_with_absmags==True:
    mag_cols = [f"magnitude_{f}" for f in 'griz']
    mag_true_cols = [f"magnitude_{f}_true" for f in 'griz']
    mock_cat[mag_cols] = mock_cat[mag_cols].subtract(mock_cat['mag_dm'], axis=0)
    mock_cat[mag_true_cols] = mock_cat[mag_true_cols].subtract(mock_cat['mag_dm'], axis=0)

mock_cat[:3]
# Out:
#    model  N_filt    teff  logg  feh  magnitude_g  magnitude_g_err_sim  \
# 0   24.0     4.0  2700.0   3.0  0.0     3.098432             0.630960
# 1   24.0     4.0  2700.0   3.0  0.0     3.866981             0.087357
# 2   24.0     4.0  2700.0   3.0  0.0     5.468244             2.434158
#
#    magnitude_r  magnitude_r_err_sim  magnitude_i  magnitude_i_err_sim  \
# 0          NaN             2.699621     0.563960             0.104061
# 1     2.607157             0.043045     0.434596             0.057788
# 2          NaN                  NaN     0.362840             0.644691
#
#    magnitude_z  magnitude_z_err_sim     mag_dm  magnitude_g_true  \
# 0    -0.637992             0.203995  18.736889           3.81947
# 1    -0.577465             0.100774  16.274684           3.81947
# 2    -0.220421             0.866037  19.773392           3.81947
#
#    magnitude_r_true  magnitude_i_true  magnitude_z_true
# 0           2.56048          0.507095         -0.555312
# 1           2.56048          0.507095         -0.555312
# 2           2.56048          0.507095         -0.555312

# %%
#--- Save mock catalog to csv ---
mock_cat.to_csv(f"{base_dir}/{local_dir}/{sed_name}_mock.csv", index=False)

# %% [markdown]
# ## 3. **zphota**

# %% [markdown]
# ### 3.1 Convert mock to lephare input

# %%
#--- Run if no Ids in your table ---
def add_ids(df, base_id):
    n = len(df)
    width = len(str(n-1))
    df.insert(0, "mock_id", 0)
    df["mock_id"] = str(base_id) + pd.Series(range(n)).astype(str).str.zfill(width)
    
    return df

cat_path = f"{base_dir}/{local_dir}/{sed_name}_mock.csv"
temp = pd.read_csv(cat_path)
temp = add_ids(temp, 123456)
temp.to_csv(cat_path, index=False)

# %%
#--- Transfrom csv formated catalog to .dat, valid for lephare ---
csv_in = f"{base_dir}/{local_dir}/{sed_name}_mock.csv"
dat_out = f"{base_dir}/{local_dir}/{sed_name}_mock.dat"

#--- csv cols to use. To be set in right order ---
input_columns = ['mock_id', 
    'magnitude_g', 'magnitude_r', 'magnitude_i', 'magnitude_z',
    'magnitude_g_err_sim', 'magnitude_r_err_sim', 'magnitude_i_err_sim', 'magnitude_z_err_sim']

format_to_lephareinput(CAT_IN=csv_in,
    CAT_OUT=dat_out,
    input_columns=input_columns,
    n_filters=4,
    CAT_TYPE='long', #short = ident + mags +errmags, long += context + zspec
    simple_convert=False,
    apply_context = 'yes', #compute lephare context from non-valid columns
    facticious_specz = 0., #add/replace same specz value for all source
    shuffle=False,
    max_rows=None,
    error_value_state='default' #If default, nan --> 99
    )
# Out:
# [INFO] Added missing 'context' column automatically.
# [INFO] Replacing 16079 missing values with 99.0
# [INFO] Added constant spec-z column with value 0.0
# [OK] Catalog saved → /home/hallouin/Documents/t_hall/lephare-u-Tototime-sedlib-calibration/calibration/data/tests/bt_spectra_logg3.0feh0.0/logg3.0feh0.0_mock.dat

# %% [markdown]
# ### 3.2 Prepare

# %%
config.update({
        "ZPHOTLIB": f"{maglib_prefix}{sed_name}",
        "SPEC_OUT": "NO",
        "CAT_IN": dat_out,
        "INP_TYPE": "M",
        "CAT_TYPE": "LONG",
        "CAT_MAG": "AB",
        "PARA_OUT": f"{base_dir}/stargal_output.para",
        "CAT_OUT": f"{base_dir}/{local_dir}/{sed_name}_mock.out",
        "AUTO_ADAPT": "NO",
        "PDZ_TYPE": "MIN_ZG",
        "CAT_FMT": "MMEE",
        "ERR_SCALE": 0,
        "SPEC_OUT": "NO",
        "CHI2_OUT": "NO",
        "RM_DISCREPENT": 1e9,
    })

zphota = lp.PhotoZ(lp.all_types_to_keymap(config))
# Out:
# #######################################
# # PHOTOMETRIC REDSHIFT with OPTIONS   #
# # Config file            :
# # CAT_IN                 : /home/hallouin/Documents/t_hall/lephare-u-Tototime-sedlib-calibration/calibration/data/tests/bt_spectra_logg3.0feh0.0/logg3.0feh0.0_mock.dat
# # CAT_OUT                : /home/hallouin/Documents/t_hall/lephare-u-Tototime-sedlib-calibration/calibration/data/tests/bt_spectra_logg3.0feh0.0/logg3.0feh0.0_mock.out
# # CAT_LINES              : 0 1000000000
# # PARA_OUT               : /home/hallouin/Documents/t_hall/lephare-u-Tototime-sedlib-calibration/calibration/stargal_output.para
# # INP_TYPE               : M
# # CAT_FMT[0:MEME 1:MMEE] : 1
# # CAT_MAG                : AB
# # ZPHOTLIB               : BT_LSST_griz_logg3.0feh0.0
# # FIR_LIB                :
# # FIR_LMIN               : 7.000000
# # FIR_CONT               : -1.000000
# # FIR_SCALE              : -1.000000
# # FIR_FREESCALE          : YES
# # FIR_SUBSTELLAR         : NO
# # ERR_SCALE              : 0.000000
# # ERR_FACTOR             : 1.000000
# # GLB_CONTEXT            : -1
# # FORB_CONTEXT           : -1
# # DZ_WIN                 : 1.000000
# # MIN_THRES              : 0.020000
# # MAG_ABS                : -24.000000 -5.000000
# # MAG_ABS_AGN            : -30.000000 -10.000000
# # MAG_REF                : 3
# # NZ_PRIOR               : -1 -1
# # Z_INTERP               : YES
# # Z_METHOD               : BEST
# # MABS_METHOD            : 1
# # MABS_CONTEXT           : 33556478
# # MABS_REF               : 11
# # AUTO_ADAPT             : NO
# # ADAPT_BAND             : 5
# # ADAPT_LIM              : 1.500000 23.000000
# # ADAPT_ZBIN             : 0.010000 6.000000
# # ZFIX                   : NO
# # SPEC_OUT               : NO
# # CHI_OUT                : NO
# # PDZ_OUT                : NONE
# #######################################
# Reading input librairies ...
# Read lib
# Number of keywords to be read in the doc: 13
# Number of keywords read at the command line (excluding -c config): 0
# Reading keywords from /home/hallouin/.cache/lephare/work/lib_mag/BT_LSST_griz_logg3.0feh0.0.doc
# Number of keywords read in the config file: 16
# Keyword NUMBER_ROWS not provided
# Keyword NUMBER_SED not provided
# Keyword Z_FORM not provided
# Reading library: /home/hallouin/.cache/lephare/work/lib_mag/BT_LSST_griz_logg3.0feh0.0.bin
#  Done with the library reading with 88 SED read.
# Read lib out
# Read filt
# # NAME                        IDENT      Lbda_mean Lbeff(Vega)       FWHM     AB-cor      VEGA   CALIB    Fac_corr
# BuzzardLSSTg.res              1             0.4799      0.4700      0.1453   -0.0893  -20.7000       0      1.0000
# BuzzardLSSTr.res              2             0.6221      0.6133      0.1391    0.1458  -21.5100       0      1.0000
# BuzzardLSSTi.res              3             0.7541      0.7475      0.1302    0.3662  -22.1500       0      1.0000
# BuzzardLSSTz.res              4             0.8682      0.8659      0.1011    0.5171  -22.6100       0      1.0000

# %% [markdown]
# ### 3.3 RUN

# %%
#--- Prepare ---
cat = np.loadtxt(dat_out)
id = cat[:, 0]
mag = cat[:, 1:5]
emag = cat[:, 5:9]
context = cat[:, 9]
zspec = cat[:, 10]
srclist = []
n = np.min((len(cat), max_row_lephare))
for i in range(n):
    oneObj = lp.onesource(i, zphota.gridz)
    oneObj.readsource(str(id[i]), mag[i, :], emag[i, :], int(context[i]), zspec[i], " ")
    zphota.prep_data(oneObj)
    srclist.append(oneObj)

#--- Run ---
zphota.run_photoz(srclist[:n], [0,0,0,0])
final = zphota.build_output_tables(srclist[:n], filename=f"{base_dir}/{local_dir}/{sed_name}_mock.fits")

final[:3]
# Out:
# <Table length=3>
#    IDENT      Z_BEST  Z_MED  ...  ZSPEC  PDF_MIN_ZG()
#    str12     float64 float64 ... float64  float64[2]
# ------------ ------- ------- ... ------- ------------
# 1234560000.0   -99.9   -99.9 ...     0.0   0.0 .. 0.0
# 1234560001.0   -99.9   -99.9 ...     0.0   0.0 .. 0.0
# 1234560002.0   -99.9   -99.9 ...     0.0   0.0 .. 0.0

# %% [markdown]
# Cleaning files

# %%
if clean_seds == True:
    sed_grid_path = f'{base_dir}/{local_dir}/{list_name}.list'
    with open(sed_grid_path, 'r') as file:
                for line in file:
                    line = line.strip()
                    if line.startswith('#') or not line:
                        continue
                    file_path = line.split()[0]
                    print(file_path)
                    os.remove(file_path)

if clean_cache == True:
    maglib_path = f'{cache_dir}/{maglib_prefix}{sed_name}'
    ends = [".bin", ".dat", ".doc"]
    for end in ends:
        os.remove(f"{maglib_path}{end}")

# %% [markdown]
# ## **4. Statistic**

# %% [markdown]
# ### 4.1 Lephare Chi2 Distribution

# %%
#--- Supposing a Chi2 distribution of the fitting parameter, compute the df of this distribution ---
import scipy.stats as stats

# fitting dist
chi_star = final[final["NBAND_USED"]==4]["CHI_STAR"]
chi_star = chi_star[chi_star<50]

df, loc, scale = stats.chi2.fit(chi_star, floc=0, fscale=1.0)
x = np.linspace(min(chi_star), max(chi_star), 1000)
pdf = stats.chi2.pdf(x, 0, loc, scale)

# plot
plt.figure(figsize=(6,5))
plt.hist(chi_star, bins=100, density=True, alpha=0.5, edgecolor='black', label='chi2 bins')
plt.plot(x, pdf, 'r-', label='fit')

# add fit values
plt.text(0.95, 0.95,
    f"df = {df:.2f}\nloc = {loc:.2f}\nscale = {scale:.2f}\nmode = {x[np.argmax(pdf)]:.2f}",
    transform=plt.gca().transAxes,
    verticalalignment='top',
    horizontalalignment='right',)

#
plt.ylim(0,1)
plt.xlabel("chi2 bins", fontsize = 12)
plt.ylabel("Proportion per bins, normalized", fontsize = 12)
plt.legend(fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 Compute our own chi2

# %%
def compute_chi2(df, bands = ['u','g','r','i','z','y']):

    #--- init ---
    chi2_array = np.zeros(len(df))
    N_used_array = df['N_filt'].values.copy()
        
    # ---vectorize over bands---
    for band in bands:
        # convert to flux
        obs = 10**(-0.4*df[f'magnitude_{band}'])
        true = 10**(-0.4*df[f'magnitude_{band}_true'])
        err = np.log(10)/2.5*obs*df[f'magnitude_{band}_err_sim']

        # obs = df[f'magnitude_{band}']
        # true = df[f'magnitude_{band}_true']
        # err = df[f'magnitude_{band}_err_sim']
        
        #delete nan columns
        valid_mask = obs.notna() & true.notna() & err.notna() & (err != 0)

        #--- compute chi2 ---
        chi2_array += ((obs - true)**2 / err**2).where(valid_mask, 0)

        #lower N_flit
        N_used_array -= (~valid_mask).astype(int)

    # Add columns to df
    df['chi2'] = chi2_array
    df['N_filt'] = N_used_array

    return df

# %%
test = compute_chi2(mock_cat, bands = ['g','r','i','z'])

# %%
import scipy.stats as stats
# %matplotlib inline

# fitting dist
chi_star = test[test["N_filt"]==4]["chi2"]#N_filt mask
chi_star = chi_star[chi_star<30]

df, loc, scale = stats.chi2.fit(chi_star, floc=0, fscale=1)
x = np.linspace(min(chi_star), max(chi_star), 1000)
pdf = stats.chi2.pdf(x, df, loc, scale)

# plot
plt.figure(figsize=(6,5))
plt.hist(chi_star, bins=50, density=True, alpha=0.5, edgecolor='black', label='chi2 bins')
plt.plot(x, pdf, 'r-', label='fit')

# add fit values
plt.text(0.95, 0.95,
    f"df = {df:.2f}\nloc = {loc:.2f}\nscale = {scale:.2f}",
    transform=plt.gca().transAxes,
    verticalalignment='top',
    horizontalalignment='right',)

#
# plt.ylim(0,1)
plt.xlabel("chi2 bins", fontsize = 12)
plt.ylabel("Proportion per bins, normalized", fontsize = 12)
plt.legend(fontsize = 12)
plt.tight_layout()
plt.show()
