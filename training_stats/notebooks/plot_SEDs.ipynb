# %% [markdown]
# # Plot some SEDs for DC1

# %%
# %matplotlib widget
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 
matplotlib.rc('ytick', labelsize=14)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rcParams.update({'font.size': 18})

base_dir = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/buzzard_base/SEDS'
SED_folder = os.path.join(base_dir, 'updated_Buzzard_SEDs')


plt.figure(figsize=(10, 6))

for i, SED in enumerate(os.listdir(SED_folder)):
    if i%19!=0:  # Adjust if your SED files use a different extension
        continue
    file = os.path.join(SED_folder, f'{SED}')
    df = np.loadtxt(file)
    plt.loglog(df.T[0], df.T[1], label=f'{SED}')

# plt.title("SEDs")
plt.xlabel("Wavelength (A)")
plt.axvspan(2500, 12000, color='gray', alpha=0.1, label='SDSS filter region')
# plt.xlim(2500,12000)
# plt.ylim(1e-3,12000)
plt.ylabel("Transmission (Normed at 800A)")
# plt.legend()
plt.show()

# %% [markdown]
# # Plot some SEDs for DES

# %%
# %matplotlib widget
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 
matplotlib.rc('ytick', labelsize=14)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rcParams.update({'font.size': 12})

SED_folder = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin'

print(os.listdir(SED_folder))
plt.figure(figsize=(10, 6))

for i, SED in enumerate(os.listdir(SED_folder)):
    if SED.endswith('.sed'):  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder, f'{SED}')
        df = np.loadtxt(file)
        plt.loglog(df.T[0], df.T[1], label=f'{SED}')

# plt.title("SEDs")
plt.xlabel("Wavelength (A)")
plt.axvspan(2500, 12000, color='gray', alpha=0.1, label='SDSS filter region')
# plt.xlim(2500,12000)
# plt.ylim(1e-3,12000)
plt.ylabel("Transmission (Normed at 800A)")
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ## Plot White dwarves SED

# %%
# %matplotlib widget
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 
matplotlib.rc('ytick', labelsize=14)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rcParams.update({'font.size': 12})

SED_folder = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/WD'


plt.figure(figsize=(7, 3))

for i, SED in enumerate(os.listdir(SED_folder)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder, f'{SED}')
        df = np.loadtxt(file)
        plt.loglog(df.T[0], df.T[1], label=f'{SED}')

# plt.title("SEDs")
plt.xlabel("Wavelength (A)")
plt.axvspan(2500, 12000, color='gray', alpha=0.1, label='SDSS filter region')
# plt.xlim(2500,12000)
# plt.ylim(1e-3,12000)
plt.ylabel("Transmission (Normed at 800A)")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Plot particular type of star SED

# %%
# %matplotlib widget
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 
matplotlib.rc('ytick', labelsize=12)
matplotlib.rc('xtick', labelsize=12)
matplotlib.rcParams.update({'font.size': 10})

SED_folder_O = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/O'
SED_folder_B = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/B'
SED_folder_A = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/A'
SED_folder_F = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/F'
SED_folder_G = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/G'
SED_folder_K = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/K'
SED_folder_M = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/M'


SED_folder_WK = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/WK'
SED_folder_RK = '/home/hallouin/Documents/thall_2025/photoz/lephare/training_stats/simulation_catalogs/DES/DES_STARCAT/WORK_COMPLETE2/lib_bin/RK'

plt.figure(figsize=(7, 4))


print(len(os.listdir(SED_folder_O)))
for i, SED in enumerate(os.listdir(SED_folder_O)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_O, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='b')

print(len(os.listdir(SED_folder_B)))
for i, SED in enumerate(os.listdir(SED_folder_B)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_B, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='purple')

print(len(os.listdir(SED_folder_A)))
for i, SED in enumerate(os.listdir(SED_folder_A)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_A, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='k')

print(len(os.listdir(SED_folder_F)))
for i, SED in enumerate(os.listdir(SED_folder_F)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_F, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='r')

print(len(os.listdir(SED_folder_G)))
for i, SED in enumerate(os.listdir(SED_folder_G)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_G, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='g')

print(len(os.listdir(SED_folder_K)))
for i, SED in enumerate(os.listdir(SED_folder_K)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_K, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='orange')

print(len(os.listdir(SED_folder_M)))
for i, SED in enumerate(os.listdir(SED_folder_M)):
    if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
        file = os.path.join(SED_folder_M, f'{SED}')
        df = np.loadtxt(file)
        plt.plot(df.T[0], df.T[1], label=f'{SED}', c='pink')

# print(len(os.listdir(SED_folder_WK)))
# for i, SED in enumerate(os.listdir(SED_folder_WK)):
#     if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
#         file = os.path.join(SED_folder_WK, f'{SED}')
#         df = np.loadtxt(file)
#         plt.plot(df.T[0], df.T[1], label=f'{SED}', c='y')

# print(len(os.listdir(SED_folder_RK)))
# for i, SED in enumerate(os.listdir(SED_folder_RK)):
#     if SED!='STAR_MOD.list':  # Adjust if your SED files use a different extension
#         file = os.path.join(SED_folder_RK, f'{SED}')
#         df = np.loadtxt(file)
#         plt.plot(df.T[0], df.T[1], label=f'{SED}', c='teal')


# plt.title("SEDs")
plt.xlabel("Wavelength (A)")
plt.axvspan(3500, 11000, color='gray', alpha=0.1, label='SDSS filter region')
plt.xlim(3450, 11050)
plt.ylim(1e-3,10)
plt.ylabel("Transmission (Normed at 550A)")
plt.tight_layout()
# plt.legend()
plt.show()
# Out:
# 2
# 19
# 13
# 16
# 16
# 20
# 21
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
from matplotlib import cm
from matplotlib.colors import to_hex

from matplotlib.colors import Normalize
from matplotlib.cm import get_cmap
from matplotlib.colors import to_hex


matplotlib.rc('ytick', labelsize=12)
matplotlib.rc('xtick', labelsize=12)
matplotlib.rcParams.update({'font.size': 8})



def plot_seds_colormap_by_value(folder, cmap_name='plasma', cmin=0, cmax=None):

        # Read sed list and delete cache folder path
    with open(list_file, 'r') as f:
        valid_files = [line.split()[0].replace("PICKLES/", "") for line in f if line.strip()]

    # List existing files in folders
    files = [f for f in os.listdir(folder) if f in valid_files]

    if not files:
        print(f"Aucun fichier SED valide trouvé dans {folder} avec {list_file}")
        return

    vals = []

    # Étape 1 : récupérer les valeurs (ici, df.T[1][0] = valeur caractéristique du SED)
    for SED in files:
        file = os.path.join(folder, f'{SED}')
        df = np.loadtxt(file)
        vals.append(df.T[1][df.T[0]==3850])

    vals = np.array(vals)

    # Étape 2 : normalisation personnalisée
    vmin = cmin if cmin is not None else vals.min()
    vmax = cmax if cmax is not None else vals.max()
    norm = Normalize(vmin=vmin, vmax=vmax)
    cmap = get_cmap(cmap_name)

    # Étape 3 : tracé avec couleur normalisée
    for SED, val in zip(files, vals):
        file = os.path.join(folder, f'{SED}')
        df = np.loadtxt(file)
        color = to_hex(cmap(norm(val)))
        plt.loglog(df.T[0], df.T[1], label=SED, color=color)






plt.figure(figsize=(8, 5))

plot_seds_colormap_by_value(SED_folder_O, 'Blues')
plot_seds_colormap_by_value(SED_folder_B, 'Purples')
plot_seds_colormap_by_value(SED_folder_A, 'Greys')
plot_seds_colormap_by_value(SED_folder_F, 'Reds')
plot_seds_colormap_by_value(SED_folder_G, 'Greens')
plot_seds_colormap_by_value(SED_folder_K, 'Oranges')
plot_seds_colormap_by_value(SED_folder_M, 'RdPu')

plt.xlabel("Wavelength (A)")
plt.axvspan(3500, 11000, color='gray', alpha=0.1, label='SDSS filter region')
plt.xlim(3450, 11050)
plt.ylim(1e-3, 10)
plt.ylabel("Transmission (Normed at 550A)")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_7532/2802292721.py:47: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap(cmap_name)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
